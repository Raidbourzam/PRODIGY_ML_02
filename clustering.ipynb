# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
n_clusters = 8

# %%
data = pd.read_csv("Mall_Customers.csv")

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.drop('CustomerID',axis=1,inplace=True)

# %%
data['Gender'] = data['Gender'].map({'Male': 1, 'Female': 0})

# %%
data.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0       1   19                  15                      39
# 1       1   21                  15                      81
# 2       0   20                  16                       6
# 3       0   23                  16                      77
# 4       0   31                  17                      40

# %%
kmeans = KMeans(n_clusters=n_clusters, random_state=42)

# %%
kmeans.fit(data)
# Out:
# KMeans(random_state=42)

# %%
clusters = kmeans.predict(data)

# %%
data['Cluster'] = clusters

# %%
print("Centres des clusters :\n", kmeans.cluster_centers_)
# Out:
# Centres des clusters :
#  [[  0.43181818  56.34090909  53.70454545  49.38636364]
#  [  0.42857143  33.         114.71428571  78.42857143]
#  [  0.46875     32.625       80.375       82.9375    ]
#  [  0.68        41.96        79.64        15.4       ]
#  [  0.40909091  25.27272727  25.72727273  79.36363636]
#  [  0.40909091  44.31818182  25.77272727  20.27272727]
#  [  0.34210526  27.          56.65789474  49.13157895]
#  [  0.3         41.         109.7         22.        ]]

# %%
plt.scatter(data['Gender'], data['Age'], c=clusters, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='o')
plt.title('Clusters KMeans')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()
